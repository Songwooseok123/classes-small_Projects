# %%
from google.colab import drive
drive.mount('/content/drive')

# !wget -q https://dlcdn.apache.org/spark/spark-3.3.1/spark-3.3.1-bin-hadoop3.tgz
# !tar xf spark-3.3.1-bin-hadoop3.tgz
# !pip install -q findspark

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.3.1-bin-hadoop3"

import findspark
findspark.init()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Spark Context 만들기 
from pyspark import SparkContext
sc = SparkContext("local","first app")

# %%
data = sc.textFile("/content/drive/MyDrive/Colab Notebooks/데이터분석을위한프로그래밍/input1.txt",1)

print(data.count())
print(data.take(3))
# Out:
# 1000
# ['(2, 96)', '(19, 78)', '(13, 83)']

# %%
#첫 pair의 first element값
A= data.map(lambda x :eval(x)[0]).first()

#모든 pair의 first element 중에 max값
B=data.map(lambda x :eval(x)[0]).max()

#모든 pair의 second element 중에 min값
C= data.map(lambda x :eval(x)[1]).min()
#First element가 1인 pair의 개수
D = data.map(lambda x :eval(x)[0]).filter(lambda x: x==1).count()

#First element가 2인 pair의 개수
e = data.map(lambda x :eval(x)[0]).filter(lambda x: x==2).count()
# Out:
# 32

# %%
#첫 pair의 first element값 :
a=data.map(lambda x:eval(x)[0]).first()

#모든 pair의 first element 중에 max값
b=data.map(lambda x:eval(x)[0]).max()


#모든 pair의 second element 중에 min값
c=data.map(lambda x:eval(x)[1]).min()

#First element가 1인 pair의 개수
d=data.map(lambda x:eval(x)[0]).filter(lambda x:x==1).count()


#First element가 2인 pair의 개수
e=data.map(lambda x:eval(x)[0]).filter(lambda x:x==2).count()

print("답은",a+b+c+d+e)
# Out:
# 답은 143

# %%
data= sc.parallelize([('a',1),('b',2),('c',3),('d',4),('a','dsfads')])

data.countByKey()
# Out:
# defaultdict(int, {'a': 2, 'b': 1, 'c': 1, 'd': 1})

# %%
data =sc.parallelize([1,2,3,4,5,6,7,8],3)

data.glom().collect()
# Out:
# [[1, 2], [3, 4], [5, 6, 7, 8]]

# %%
def se(x):
  yield sum(x)
data.mapPartitions(se).collect()
# Out:
# [3, 7, 26]

# %%
data =sc.parallelize([('a',['apple','banana','lemon']),('b',['grapes'])])
data.mapValues(lambda x: len(x)).collect()
# Out:
# [('a', 3), ('b', 1)]
