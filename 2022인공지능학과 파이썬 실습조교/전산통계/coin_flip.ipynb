# %%
import random
import matplotlib.pyplot as plt

def coin_flip_experiment(num_flips):
    results = []
    zz= []
    head_count = 0

    for _ in range(num_flips):
        outcome = random.choice(["Heads", "Tails"])
        zz.append(outcome)
        if outcome == "Heads":
            head_count += 1
        probability = head_count / (len(results) + 1)  # 앞면이 나온 확률 계산
        results.append(probability)
        #print(outcome,probability)
        #print(results)
    return results,zz

num_flips = 1000
results = coin_flip_experiment(num_flips)[0]
#zzz = coin_flip_experiment(num_flips)[1]

# 그래프 그리기
plt.plot(range(1, num_flips + 1), results)
plt.xlabel("시행 횟수")
plt.ylabel("앞면 확률")
plt.title(f"동전 던지기 실험 결과 (최종 확률: {results[-1]:.2f})")
plt.show()
#print(results)
#print(zzz)

# %%
import random
import matplotlib.pyplot as plt

def coin_flip_experiment(num_flips):
    results = []
    head_count = 0

    for _ in range(num_flips):
        outcome = random.choice(["Heads", "Tails"])
        if outcome == "Heads":
            head_count += 1
        probability = head_count / (len(results) + 1)  # 앞면이 나온 확률 계산
        results.append(probability)

    return results

num_flips = 1000
results = coin_flip_experiment(num_flips)

# 그래프 그리기
plt.plot(range(1, num_flips + 1), results)
plt.xlabel("시행 횟수")
plt.ylabel("앞면 확률")
plt.title(f"동전 던지기 실험 결과 (최종 확률: {results[-1]:.2f})")
plt.show()

# %%
len(zzz)
# Out:
# 1000

# %%
import random
import matplotlib.pyplot as plt

def coin_flip_experiment(num_flips):
    results = []
    head_count = 0

    for _ in range(num_flips):
        outcome = random.choice(["Heads", "Tails"])
        if outcome == "Heads":
            head_count += 1
        probability = head_count / (len(results) + 1)  # 앞면이 나온 확률 계산
        results.append(probability)

    return results

num_flips = 1000
results = coin_flip_experiment(num_flips)

# 그래프 그리기
plt.plot(range(1, num_flips + 1), results)
plt.xlabel("시행 횟수")
plt.ylabel("앞면 확률")
plt.title(f"동전 던지기 실험 결과 (최종 확률: {results[-1]:.2f})")
plt.show()

# %%
import numpy as np
import pandas as pd
data = np.array([164, 292, 102, 153, 139,18, 92, 236, 241, 202, 31, 24, 145, 188, 293, 204, 32, 220, 154, 131, 45, 214, 62, 188, 129, 171, 161, 151, 142, 118, 171, 190, 129, 115, 168, 94, 230, 139, 100, 99, 99, 72, 103, 109, 176, 111, 59, 44, 140, 135])
table = pd.crosstab(index = data,
                    colnames = ['data'],
                    columns = 'Frequency',
                    margins = True
                    )
table.index = np.append(np.unique(data).astype(str),'total')

for i in range(46):
  table.iloc[i,1] = table.iloc[i,1]/table.iloc[45,0]
table.rename(columns = {'All':'Relative Freq'}
             ,inplace =True
             )
print(table)
# Out:
# data   Frequency  Relative Freq
# 18             1           0.02
# 24             1           0.02
# 31             1           0.02
# 32             1           0.02
# 44             1           0.02
# 45             1           0.02
# 59             1           0.02
# 62             1           0.02
# 72             1           0.02
# 92             1           0.02
# 94             1           0.02
# 99             2           0.04
# 100            1           0.02
# 102            1           0.02
# 103            1           0.02
# 109            1           0.02
# 111            1           0.02
# 115            1           0.02
# 118            1           0.02
# 129            2           0.04
# 131            1           0.02
# 135            1           0.02
# 139            2           0.04
# 140            1           0.02
# 142            1           0.02
# 145            1           0.02
# 151            1           0.02
# 153            1           0.02
# ...

# %%
k = 10
lower_limit = np.min(data) - 0.5
upper_limit = np.max(data) + 0.5
width = (upper_limit - lower_limit) / k

# %%
intervals = []
for i in range(k):
    l = round(lower_limit + i * width, 3)
    u = round(lower_limit + (i+1) * width, 3)
    intervals.append((l, u))
class_interval = [f'{lower} - {upper}' for (lower, upper) in intervals]

# %%
lower_limit
# Out:
# 17.5

# %%
interval_index = ((data - lower_limit) // width).astype(int)
# Out:
# 0.02

# %%
len(np.append(np.unique(data).astype(str),'total'))
# Out:
# 46

# %%
np.array(['z'])+np.array(['z'])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-85-f175a07803c3> in <cell line: 1>()
# ----> 1 np.array(['z'])+np.array(['z'])
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U1'), dtype('<U1')) -> None

# %%
len(list(data.astype('str')) +['total'])
# Out:
# 51

# %%
aa= data
list(set(aa)).sort()
aa
# Out:
# array([164, 292, 102, 153, 139,  18,  92, 236, 241, 202,  31,  24, 145,
#        188, 293, 204,  32, 220, 154, 131,  45, 214,  62, 188, 129, 171,
#        161, 151, 142, 118, 171, 190, 129, 115, 168,  94, 230, 139, 100,
#         99,  99,  72, 103, 109, 176, 111,  59,  44, 140, 135])

# %%
data.sort()

# %%
data_value = list(set(data))
data_value.sort()
data_value
# Out:
# [18,
#  24,
#  31,
#  32,
#  44,
#  45,
#  59,
#  62,
#  72,
#  92,
#  94,
#  99,
#  100,
#  102,
#  103,
#  109,
#  111,
#  115,
#  118,
#  129,
#  131,
#  135,
#  139,
#  140,
#  142,
#  145,
#  151,
#  153,
#  154,
#  161,
#  164,
#  168,
#  171,
#  176,
#  188,
#  190,
#  202,
#  204,
#  214,
#  220,
#  230,
#  236,
#  241,
#  292,
#  293]
